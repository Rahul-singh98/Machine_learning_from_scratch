# %% [markdown]
# ## Data Science Practise using ted-talks dataset

# %% [markdown]
# Exploratory Data Analysis is all about answering a specific questions.
# 1. Which talks provoke the most online discussion?
# 2. What are the best events in ted history to attend?
# 3. Which occupations deliver the funniest TED talks on average?

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_style('whitegrid')

plt.rcParams['figure.figsize'] = [12, 10]

# %% [markdown]
# ### Data

# %%
ted = pd.read_csv('../data_library/ted_main.csv')
ted.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
ted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2550 entries, 0 to 2549
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   comments            2550 non-null   int64
#  1   description         2550 non-null   object
#  2   duration            2550 non-null   int64
#  3   event               2550 non-null   object
#  4   film_date           2550 non-null   int64
#  5   languages           2550 non-null   int64
#  6   main_speaker        2550 non-null   object
#  7   name                2550 non-null   object
#  8   num_speaker         2550 non-null   int64
#  9   published_date      2550 non-null   int64
#  10  ratings             2550 non-null   object
#  11  related_talks       2550 non-null   object
#  12  speaker_occupation  2544 non-null   object
#  13  tags                2550 non-null   object
#  14  title               2550 non-null   object
# ...

# %%
# Count the number of missing values in each coloum
ted.isna().sum()
# Out:
# comments              0
# description           0
# duration              0
# event                 0
# film_date             0
# languages             0
# main_speaker          0
# name                  0
# num_speaker           0
# published_date        0
# ratings               0
# related_talks         0
# speaker_occupation    6
# tags                  0
# title                 0
# url                   0
# views                 0
# dtype: int64

# %%
ted['speaker_occupation'] = ted.speaker_occupation.fillna(ted.speaker_occupation.mode()[0])

# %%
ted.describe()
# Out:
#           comments     duration     film_date    languages  num_speaker  \
# count  2550.000000  2550.000000  2.550000e+03  2550.000000  2550.000000
# mean    191.562353   826.510196  1.321928e+09    27.326275     1.028235
# std     282.315223   374.009138  1.197391e+08     9.563452     0.207705
# min       2.000000   135.000000  7.464960e+07     0.000000     1.000000
# 25%      63.000000   577.000000  1.257466e+09    23.000000     1.000000
# 50%     118.000000   848.000000  1.333238e+09    28.000000     1.000000
# 75%     221.750000  1046.750000  1.412964e+09    33.000000     1.000000
# max    6404.000000  5256.000000  1.503792e+09    72.000000     5.000000
#
#        published_date         views
# count    2.550000e+03  2.550000e+03
# mean     1.343525e+09  1.698297e+06
# std      9.464009e+07  2.498479e+06
# min      1.151367e+09  5.044300e+04
# 25%      1.268463e+09  7.557928e+05
# 50%      1.340935e+09  1.124524e+06
# 75%      1.423432e+09  1.700760e+06
# ...

# %%
sns.pairplot(ted)

# %% [markdown]
# ### Q1. Which talks provoke the most online discussion?

# %%
ted.hist(edgecolor='black', linewidth=1.2, figsize=(12,10));

# %%
plt.figure(figsize=(12,10))
sns.heatmap(ted.corr() , annot=True);

# %%
ted.languages.value_counts().hist();

# %%
ted.sort_values('comments').tail()
# Out:
#       comments                                        description  duration  \
# 1787      2673  Our consciousness is a fundamental aspect of o...      1117
# 201       2877  Jill Bolte Taylor got a research opportunity f...      1099
# 644       3356  Questions of good and evil, right and wrong ar...      1386
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 96        6404  Richard Dawkins urges all atheists to openly s...      1750
#
#         event   film_date  languages       main_speaker  \
# 1787  TED2014  1395100800         33     David Chalmers
# 201   TED2008  1204070400         49  Jill Bolte Taylor
# 644   TED2010  1265846400         39         Sam Harris
# 0     TED2006  1140825600         60       Ken Robinson
# 96    TED2002  1012608000         42    Richard Dawkins
#
#                                                    name  num_speaker  \
# 1787  David Chalmers: How do you explain consciousness?            1
# ...

# %% [markdown]
# ### Limitations of this approach:
# 1. sub comments (nested comments).
# 1. how long its being online.
# ### To correct this behavior, one solution is to normalise comments by views

# %%
# creating a new column 'comments_per_view'
ted['comments_per_view'] = ted.comments / ted.views

# interpretation: for every view of the same-sex marriage talk, there are 0.002 comments
ted.sort_values('comments_per_view').tail()
# Out:
#      comments                                        description  duration  \
# 954      2492  Janet Echelman found her true voice as an arti...       566
# 694      1502  Filmmaker Sharmeen Obaid-Chinoy takes on a ter...       489
# 96       6404  Richard Dawkins urges all atheists to openly s...      1750
# 803       834  David Bismark demos a new system for voting th...       422
# 744       649  Hours before New York lawmakers rejected a key...       453
#
#                      event   film_date  languages           main_speaker  \
# 954                TED2011  1299110400         35         Janet Echelman
# 694                TED2010  1265760000         32  Sharmeen Obaid-Chinoy
# 96                 TED2002  1012608000         42        Richard Dawkins
# 803         TEDGlobal 2010  1279065600         36          David Bismark
# 744  New York State Senate  1259712000          0        Diane J. Savino
#
#                                                   name  num_speaker  \
# ...

# %%
# create a column name 'views_per_comment'
ted['views_per_comment'] = ted.views / ted.comments

# interpretation: 1 out of every 450 people leave a comment
ted.sort_values('views_per_comment').head()
# Out:
#      comments                                        description  duration  \
# 744       649  Hours before New York lawmakers rejected a key...       453
# 803       834  David Bismark demos a new system for voting th...       422
# 96       6404  Richard Dawkins urges all atheists to openly s...      1750
# 694      1502  Filmmaker Sharmeen Obaid-Chinoy takes on a ter...       489
# 954      2492  Janet Echelman found her true voice as an arti...       566
#
#                      event   film_date  languages           main_speaker  \
# 744  New York State Senate  1259712000          0        Diane J. Savino
# 803         TEDGlobal 2010  1279065600         36          David Bismark
# 96                 TED2002  1012608000         42        Richard Dawkins
# 694                TED2010  1265760000         32  Sharmeen Obaid-Chinoy
# 954                TED2011  1299110400         35         Janet Echelman
#
#                                                   name  num_speaker  \
# ...

# %%
plt.plot(list(ted.index) , list(ted.views));

# %%
plt.subplot(2,2,1)
ted.comments.plot(kind='hist')

# modifying plot to be more informative
plt.subplot(2,2,2)
ted[ted.comments < 1000].comments.plot(kind='hist')

# increase the number of bins
plt.subplot(2,2,3)
ted.loc[ted.comments < 1000 , 'comments'].plot(kind='hist' , bins= 20)

# boxplot
plt.subplot(2,2,4)
ted[ted.comments < 1000].comments.plot(kind='box');

# %%
## Plot number of talks that took place every year
ted.event.sample(10)
# Out:
# 1432        TEDxThessaloniki
# 2219                 TED2016
# 1316         TEDxBoston 2012
# 1137           TEDWomen 2010
# 917                  TED2011
# 1367          TEDGlobal 2012
# 1984           TEDxSouthBank
# 343              Taste3 2008
# 921                  TEDxPSU
# 1835    TEDSalon Berlin 2014
# Name: event, dtype: object

# %% [markdown]
# We can'nt rely on event because most of the events doesn't have the year

# %%
pd.to_datetime(ted.film_date).head()
# Out:
# 0   1970-01-01 00:00:01.140825600
# 1   1970-01-01 00:00:01.140825600
# 2   1970-01-01 00:00:01.140739200
# 3   1970-01-01 00:00:01.140912000
# 4   1970-01-01 00:00:01.140566400
# Name: film_date, dtype: datetime64[ns]

# %% [markdown]
# Result does'nt looks good

# %%
ted['film_datetime'] = pd.to_datetime(ted.film_date , unit='s')

# verify that event name matches film_datetime for a random sample
ted[['event' , 'film_datetime']].sample(10)
# Out:
#                             event film_datetime
# 584                TEDGlobal 2009    2009-07-24
# 2257                    TEDSummit    2016-06-27
# 1444                 TEDxConcorde    2013-01-24
# 18                        TED2005    2005-02-25
# 538                        TEDxKC    2009-08-20
# 2530                      TED2017    2017-04-24
# 555          TEDSalon London 2009    2009-09-21
# 1077                  TEDMED 2011    2011-10-28
# 1394               TEDGlobal 2012    2012-06-26
# 1135  TEDSalon London Spring 2011    2011-11-11

# %%
ted.film_datetime.dt.year.value_counts()
# Out:
# 2013    270
# 2011    270
# 2010    267
# 2012    267
# 2016    246
# 2015    239
# 2014    237
# 2009    232
# 2007    114
# 2017     98
# 2008     84
# 2005     66
# 2006     50
# 2003     33
# 2004     33
# 2002     27
# 1998      6
# 2001      5
# 1983      1
# 1991      1
# 1994      1
# 1990      1
# 1984      1
# 1972      1
# Name: film_datetime, dtype: int64

# %%
ted.film_datetime.dt.year.value_counts().plot();

# %%
ted.film_datetime.dt.year.value_counts().sort_index().plot();
plt.xlim(ted.film_datetime.dt.year.min() , ted.film_datetime.dt.year.max())
# Out:
# (1972, 2017)
