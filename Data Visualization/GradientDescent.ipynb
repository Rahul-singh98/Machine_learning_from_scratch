# %% [markdown]
# ## Visualize 3d plot

# %% [markdown]
# ### imports

# %%
import numpy as np 
import pandas as pd
from sklearn.datasets import load_boston

import matplotlib as mpl 
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# load dataset
full_data = load_boston()
one_feature = full_data.data[: , np.newaxis , 1]
X = one_feature[:500]
y = full_data.target[:500]

# %%
def hypothesis(x , y):
    """
     Creating hypothesis for the data
    """
    xmean = np.mean(x)
    ymean = np.mean(y)
    
    n = len(x)
    
    numerator = 0
    denominator = 0
    
    for i in range(n):
        numerator += ((x[i] - xmean) * (y[i] - ymean))
        denominator += (x[i] - xmean)**2
        
    b1 = numerator /denominator
    b0 = ymean - (b1 * xmean)
    
    c = b0[0]
    m = b1[0]
    
    return lambda x: m*x + c

# %%
p_hypothesis = hypothesis(X , y)

# %%
pred = p_hypothesis(X)

# %%
def costfunction(truth , predicted):
    m = truth.shape[0]
    mse = (np.sum((predicted - truth)**2)) / (2 * m)
    return mse

# %%
cost = mean_squared_error_custom(y , pred)

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')

x = [1,2,3,4,5] 
y = [5,2,3,6,3]
z = np.outer([1,2,3,2,3] , [1,2,2,6,2])

ax.plot_surface(x , y , z , cmap='rainbow')

# %%
fig = plt.figure(figsize=(10,8))
ax  = fig.add_subplot(111 , projection='3d')

b0 = np.random.randn(1,1, 3000)[0][0]
b1 = b0* 2
z = np.random.randn(1,1 ,3000 )[0][0]

ploting_x = b0  
plotting_y = b1
plotting_z = z

ax.scatter(ploting_x , plotting_y , plotting_z , c='k' , s=5)
plt.show()

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')

x = [1,2,3,4,5] 
y = [5,2,3,6,3]
z = np.outer([1,2,3,2,3], [1,2,2,6,2])

ax.plot_wireframe(x , y , z , color='k')

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')

x = [1,2,3,4,5] 
y = [5,2,3,6,3]
z = np.outer([1,2,3,2,3] , [1,2,2,6,2])

ax.plot_surface(x , y , z , cmap='rainbow')

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111, projection='3d')

x = [1,2,3,4,5] 
y = [5,2,3,6,3]
z = [1,2,3,2,3]

ax.plot_trisurf(x , y , z , color='m')
