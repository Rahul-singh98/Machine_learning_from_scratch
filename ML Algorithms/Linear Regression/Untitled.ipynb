# %% [markdown]
# ## Plot trend line in stocks of Britania

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../data_library/datasets_BRITANNIA.csv")
df.head()
# Out:
#          Date     Symbol Series  Prev Close   Open    High    Low   Last  \
# 0  2000-01-03  BRITANNIA     EQ      703.25  705.0  759.50  705.0  758.0
# 1  2000-01-04  BRITANNIA     EQ      756.90  710.0  770.00  710.0  740.0
# 2  2000-01-05  BRITANNIA     EQ      754.55  755.0  759.00  705.0  740.0
# 3  2000-01-06  BRITANNIA     EQ      735.30  740.0  794.15  740.0  770.0
# 4  2000-01-07  BRITANNIA     EQ      785.65  808.0  848.50  798.0  848.5
#
#     Close    VWAP  Volume      Turnover  Trades  Deliverable Volume  \
# 0  756.90  741.01    7512  5.566488e+11     NaN                 NaN
# 1  754.55  742.52    8135  6.040391e+11     NaN                 NaN
# 2  735.30  739.92    6095  4.509784e+11     NaN                 NaN
# 3  785.65  788.83   19697  1.553756e+12     NaN                 NaN
# 4  848.50  827.53   33107  2.739708e+12     NaN                 NaN
#
#    %Deliverble
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5140 entries, 0 to 5139
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5140 non-null   object
#  1   Symbol              5140 non-null   object
#  2   Series              5140 non-null   object
#  3   Prev Close          5140 non-null   float64
#  4   Open                5140 non-null   float64
#  5   High                5140 non-null   float64
#  6   Low                 5140 non-null   float64
#  7   Last                5140 non-null   float64
#  8   Close               5140 non-null   float64
#  9   VWAP                5140 non-null   float64
#  10  Volume              5140 non-null   int64
#  11  Turnover            5140 non-null   float64
#  12  Trades              2291 non-null   float64
#  13  Deliverable Volume  4631 non-null   float64
#  14  %Deliverble         4631 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5140.000000  5140.000000  5140.000000  5140.000000  5140.000000
# mean   1626.707626  1628.720768  1651.786663  1604.847374  1627.397850
# std    1342.145383  1344.249059  1357.199831  1327.989366  1342.498478
# min     336.350000   340.000000   347.700000   295.200000   336.950000
# 25%     583.112500   584.637500   595.000000   574.750000   584.537500
# 50%    1176.825000  1172.550000  1200.000000  1147.000000  1179.500000
# 75%    2517.550000  2538.937500  2591.200000  2485.162500  2535.500000
# max    6900.150000  6918.000000  6934.350000  6831.700000  6898.000000
#
#             Close         VWAP        Volume      Turnover         Trades  \
# count  5140.00000  5140.000000  5.140000e+03  5.140000e+03    2291.000000
# mean   1627.29572  1628.354897  1.030030e+05  2.819666e+13   17031.137058
# std    1342.40290  1342.685508  2.267989e+05  7.510370e+13   19789.365337
# ...

# %%
print(df['Series'].unique())
print(df['Symbol'].unique())
# Out:
# ['EQ']
# ['BRITANNIA']

# %% [markdown]
# **Symbol** and **Series** only represents the company name and type `BRITANNIA , EQ`  so I can simply drop this column

# %%
df.drop(['Series' , 'Symbol'] , axis=1, inplace=True)

# %%
df.head()
# Out:
#          Date  Prev Close   Open    High    Low   Last   Close    VWAP  \
# 0  2000-01-03      703.25  705.0  759.50  705.0  758.0  756.90  741.01
# 1  2000-01-04      756.90  710.0  770.00  710.0  740.0  754.55  742.52
# 2  2000-01-05      754.55  755.0  759.00  705.0  740.0  735.30  739.92
# 3  2000-01-06      735.30  740.0  794.15  740.0  770.0  785.65  788.83
# 4  2000-01-07      785.65  808.0  848.50  798.0  848.5  848.50  827.53
#
#    Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0    7512  5.566488e+11     NaN                 NaN          NaN
# 1    8135  6.040391e+11     NaN                 NaN          NaN
# 2    6095  4.509784e+11     NaN                 NaN          NaN
# 3   19697  1.553756e+12     NaN                 NaN          NaN
# 4   33107  2.739708e+12     NaN                 NaN          NaN

# %%
plt.violinplot(df['Volume'])
plt.show()

# %%
plt.boxplot(df['Volume'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f29f0733940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f29f0796f60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f29f0733f28>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f29f0802588>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f29f072f710>],
#  'means': []}
